# %%
#pandas reading text files
 
import numpy as np
import pandas as pd
poke12 = pd.read_csv('pokemon_data.txt', sep=" ", header=None)
print(poke12)
print(poke12.head(5))
print(poke12.tail(5))
# Out:
#                                                      0  \
# 0                                        #\tName\tType
# 1    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 2    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 3    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 4                                      3\tVenusaurMega
# 5    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# 6    5\tCharmeleon\tFire\t\t58\t64\t58\t80\t65\t80\...
# 7    6\tCharizard\tFire\tFlying\t78\t84\t78\t109\t8...
# 8                                     6\tCharizardMega
# 9                                     6\tCharizardMega
# 10   7\tSquirtle\tWater\t\t44\t48\t65\t50\t64\t43\t...
# 11   8\tWartortle\tWater\t\t59\t63\t80\t65\t80\t58\...
# 12   9\tBlastoise\tWater\t\t79\t83\t100\t85\t105\t7...
# 13                                    9\tBlastoiseMega
# 14   10\tCaterpie\tBug\t\t45\t30\t35\t20\t20\t45\t1...
# 15   11\tMetapod\tBug\t\t50\t20\t55\t25\t25\t30\t1\...
# ...
